# %%
import pandas as pd
import numpy as np
from panelsfa import CrossSectionalSFA
# Out:
# Running cells with '.venv (3.13.5) (Python 3.13.5)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/rohit/OneDrive/Documents/GitHub/PanelSFA/.venv/Scripts/python.exe -m pip install ipykernel -U --force-reinstall'

# %%
df=pd.read_excel(r"Dairy_data.xlsx")

# %%
df

# %%
df.columns

# %%
y=df['ly'].values

# %%
X = np.column_stack([
    np.ones(len(df)),          
    df['lland'].values,
    df['llabor'].values,
    df['lfeed'].values,
    df['lcattle'].values,
])

# %%
model=CrossSectionalSFA(model_type="production")

# %%
model.fit(X,y)

# %%
model.coef_

# %%
model.log_likelihood_

# %%
model.gamma_
